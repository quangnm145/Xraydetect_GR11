# %%
# !nvidia-smi
# Out:
# Fri Feb 24 04:44:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 25.4MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...
# 100% 104k/104k [00:00<00:00, 4.99MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 13.9ms
# Speed: 0.5ms pre-process, 13.9ms inference, 53.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# %cd {HOME}/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wP4MlooC1KJuTLK537xk")
project = rf.workspace("hust-3xurl").project("xraydetec2")
dataset = project.version(3).download("yolov8")
# Out:
# /content/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 KB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 4.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=c26e68eb36068073e9c930a66a99c779bc99da3a54c2a1849a542c1b6e9b6db0
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HTbbqeE765NUaVDoIg3F")
project = rf.workspace("bkhn-huqf2").project("xraydetec5")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Xraydetec5-1 in yolov8:: 100%|██████████| 30812/30812 [00:07<00:00, 4070.42it/s]

# %%
#!cp -r /content/datasets/Xraydetec4-1/test/images/* /content/datasets/Xraydetec2-3/test/images/
# !cp -r /content/datasets/Xraydetec4-1/test/labels/* /content/datasets/Xraydetec2-3/test/labels/

# !cp -r /content/datasets/Xraydetec4-1/train/labels/* /content/datasets/Xraydetec2-3/train/labels/
# !cp -r /content/datasets/Xraydetec4-1/train/labels/* /content/datasets/Xraydetec2-3/train/labels/

# !cp -r /content/datasets/Xraydetec4-1/valid/labels/* /content/datasets/Xraydetec2-3/valid/labels/
# !cp -r /content/datasets/Xraydetec4-1/valid/labels/* /content/datasets/Xraydetec2-3/valid/labels/

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="q7oCeNOkR8bw6VutNufB")
project = rf.workspace("hust-dz9h2").project("xraydetec4")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Xraydetec4-1 in yolov8:: 100%|██████████| 30314/30314 [00:07<00:00, 4225.97it/s]

# %%
# !cp -r /content/datasets/Xraydetec5-1/test/images/* /content/datasets/Xraydetec2-3/test/images/
# !cp -r /content/datasets/Xraydetec5-1/test/labels/* /content/datasets/Xraydetec2-3/test/labels/

# !cp -r /content/datasets/Xraydetec5-1/train/labels/* /content/datasets/Xraydetec2-3/train/labels/
# !cp -r /content/datasets/Xraydetec5-1/train/labels/* /content/datasets/Xraydetec2-3/train/labels/

# !cp -r /content/datasets/Xraydetec5-1/valid/labels/* /content/datasets/Xraydetec2-3/valid/labels/
# !cp -r /content/datasets/Xraydetec5-1/valid/labels/* /content/datasets/Xraydetec2-3/valid/labels/

# %%
# !rm -r /content/datasets/Xraydetec4-1
# !rm -r /content/datasets/Xraydetec5-1
# !rm -r /content/datasets/xraydata6-1

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CN7hyQaDkyuyhAAgTS0Z")
project = rf.workspace("bkhn-3ppg8").project("xraydata6")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to xraydata6-1 in yolov8:: 100%|██████████| 5158/5158 [00:01<00:00, 2617.14it/s]

# %%
#!cp -r /content/datasets/xraydata6-1/test/images/* /content/datasets/Xraydetec2-3/test/images/
#!cp -r /content/datasets/xraydata6-1/test/labels/* /content/datasets/Xraydetec2-3/test/labels/

# !cp -r /content/datasets/xraydata6-1/train/images/* /content/datasets/Xraydetec2-3/train/images/
# !cp -r /content/datasets/xraydata6-1/train/labels/* /content/datasets/Xraydetec2-3/train/labels/

# !cp -r /content/datasets/xraydata6-1/valid/images/* /content/datasets/Xraydetec2-3/valid/images/
# !cp -r /content/datasets/xraydata6-1/valid/labels/* /content/datasets/Xraydetec2-3/valid/labels/

# %%
# !zip -r datasets.zip /content/datasets

# %%
from google.colab import files
files.download('datasets.zip')

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/Xraydetec2-3/data.yaml epochs=25 imgsz=640 batch=8 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=/content/runs/detect/train2/weights/best.pt data=/content/datasets/Xraydetec2-3/data.yaml epochs=5 imgsz=640 batch=8 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml  weights

# %%
# %cd {HOME}
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'/content/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'/content/runs/detect/train2/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/datasets/Xraydetec2-3/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11130228 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/datasets/Xraydetec2-3/valid/labels.cache... 1927 images, 0 backgrounds, 0 corrupt: 100% 1927/1927 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 121/121 [00:31<00:00,  3.85it/s]
#                    all       1927       2025      0.823      0.797      0.834      0.741
#                      1       1927        504      0.879      0.592      0.724      0.558
#                     10       1927        112      0.925      0.988      0.993      0.939
#                     11       1927        342      0.904      0.871      0.941      0.837
#                     12       1927        424      0.941      0.751      0.891      0.744
#                      2       1927        146      0.952      0.807      0.913      0.788
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/datasets/Xraydetec2-3/test/images save=True

# %%
# %cd {HOME}
from google.colab import files
files.download('/content/runs/detect/train2/weights/best.pt')
# Out:
# /content
